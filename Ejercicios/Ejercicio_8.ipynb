# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_PythonDesdeCero-Challenge/blob/main/Ejercicios/Ejercicio_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Desde Cero 🐍
#
# Pyladies Panamá 🌻
#
# 2022
#
#
# ---
#
# Day 5 - PythonDesdeCero Challenge
# * Sábado 17/Septiembre/2022
#
#
# ---
# Autor: Python

# %% [markdown]
# # Calcular el Índice de Masa Corporal (IMC)
#
# Escriba un script en Python que permita calcular el IMC
# Donde debe permitir la entrada por consola del Peso y también del tamaño de la persona
# Haga los cálculos y validemos el IMC
#
# fórmula
#
# ![image.png](data:image/png;base64,...)

# %%
peso = float(input("Introduzca su peso en (kg): "))
estatura = float(input("Introduzca su tamaño / altura en (m): "))

imc = peso / (estatura * estatura)

print(f"Su IMC es: {imc} " )
# Out:
# Introduzca su peso en (kg): 75
# Introduzca su tamaño / altura en (m): 1.60
# Su IMC es: 29.296874999999993

# %%
peso = float(input("Introduzca su peso en (kg): "))
estatura = float(input("Introduzca su tamaño / altura en (m): "))

imc = peso / estatura ** 2

print(f"Su IMC es: {imc} " )
# Out:
# Introduzca su peso en (kg): 75
# Introduzca su tamaño / altura en (m): 1.60
# Su IMC es: 29.296874999999993

# %%
print("Su IMC es: " + str(imc) )

#python 3
print("Su IMC es: {}".format(imc))

#Python 3.6
print(f"Su IMC es: {imc} " )
# Out:
# Su IMC es: 29.296874999999993
# Su IMC es: 29.296874999999993
# Su IMC es: 29.296874999999993
