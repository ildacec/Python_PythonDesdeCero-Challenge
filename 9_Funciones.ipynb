# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_PythonDesdeCero-Challenge/blob/main/9_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Desde Cero 🐍
#
# Pyladies Panamá 🌻
#
# 2022
#
#
# ---
#
# Day 6 - PythonDesdeCero Challenge
# Sábado 24/Septiembre/2022
#
# Referencia: https://www.freecodecamp.org/
#
# ---

# %% [markdown]
# # Declarando y llamado de una función

# %%
# syntax
# Declaring a function
def function_name():
    codes
    codes

def function_name(var1,var2):
    codes
    codes

    
# Calling a function
function_name()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#MAXIMO de una cadena
big = max('telescopio')
print(big)
# Out:
# t

# %%
#Definir función maximo
def maximo():
  big = max('world')
  print(big)


maximo()
# Out:
# w

# %%
#Definir función con más de un parámetro
def maximo_1(cadena):
  big = max(cadena)
  print(big)

#función sin paramétro
maximo()

#función con parámetros
maximo_1("carrusel")
maximo_1("ferrocarril")
maximo_1("television")
# Out:
# w
# u
# r
# v

# %%
#definir con retorno y 2 parámetros 
def sumar(a,b):
  total = a + b
  return total

#llamado 
print(sumar(15,5))
print(sumar('15','5'))

suma = sumar(15,5)

if suma > 100:
  print('valor mayor que 100')
else:
  print ('valor menor que 100')
# Out:
# 20
# 155
# valor menor que 100

# %%
#definir con retorno y 2 parámetros 
def oper_aritmeticas(a,b):
  suma = a + b
  print(suma)
  resta = a - b
  print(resta)
  multipli = a * b
  print(multipli)
  divi = a // b
  print(divi) 


oper_aritmeticas(25,12)
# Out:
# 37
# 13
# 300
# 2
